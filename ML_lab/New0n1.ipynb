# %%
# Hello
print('Hola')
# Out:
# Hola

# %%
#Importing the Libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing  import LabelEncoder , MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
#Step 2 Load The Datasaet
#df = pd.read_excel(Book001.xlsx)
dataset = pd.read_excel("Book001.xlsx")

# %%
dataset
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2   Unnamed: 3
# 0         Name        Age     Gender         City
# 1        Gopal         19          M    Bengaluru
# 2         Noah         45          M       Winden
# 3      Nielsen         16          M       Winden
# 4       Ulrich         40          M       Winden
# 5   Charolette         39          F      Winden
# 6       Hannah         42          F      Hawkins
# 7      Claudia         87          F        Renol
# 8     Tiedamen         94          M        Nelod
# 9        Jonas         27          M       Winden
# 10   Cathorina         43          F       German
# 11   Elizabeth         29          F       Winden
# 12      Martha         26          F       German
# 13       Angel         17          F  Pensylvenia
# 14        Babi         20          M     Tirupati

# %%
print(dataset)
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2   Unnamed: 3
# 0         Name        Age     Gender         City
# 1        Gopal         19          M    Bengaluru
# 2         Noah         45          M       Winden
# 3      Nielsen         16          M       Winden
# 4       Ulrich         40          M       Winden
# 5   Charolette         39          F      Winden
# 6       Hannah         42          F      Hawkins
# 7      Claudia         87          F        Renol
# 8     Tiedamen         94          M        Nelod
# 9        Jonas         27          M       Winden
# 10   Cathorina         43          F       German
# 11   Elizabeth         29          F       Winden
# 12      Martha         26          F       German
# 13       Angel         17          F  Pensylvenia
# 14        Babi         20          M     Tirupati
